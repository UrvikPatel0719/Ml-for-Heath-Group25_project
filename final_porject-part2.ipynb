# %% [markdown]
# ## Import Libraries

# %%
# Import libraries
from datetime import timedelta
import os

import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler


from IPython.display import display, HTML, Image
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams.update({'font.size': 20})

# Access data using Google BigQuery.
# from google.colab import auth
from google.cloud import bigquery
import bigframes.pandas as bf

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
import numpy as np

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU

import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
# Out:
# /Users/sadhikrupa/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
vital_signs_df = pd.read_csv("signs_with_AGE_all.csv")
lab_value_wc = pd.read_csv("values_all.csv")
lab_value_ph = pd.read_csv("PH_all.csv")

# %%
vital_signs_df['subject_id'].value_counts()
# Out:
# subject_id
# 16454913    4615
# 14411859    3690
# 18295542    3566
# 15689523    3301
# 10858147    3204
#             ...
# 17320563       6
# 15286220       6
# 19155097       5
# 11234187       5
# 12758384       4
# Name: count, Length: 4997, dtype: int64

# %%
# Merge on subject_id, hadm_id, stay_id, and charttime
combined_df = pd.merge(lab_value_wc,lab_value_ph, on=['subject_id', 'hadm_id',  'charttime'], how='outer')

# Sort the combined DataFrame by subject_id and charttime
combined_df = combined_df.sort_values(by=['subject_id', 'charttime'])

# %%
# Merge the DataFrames on subject_id, hadm_id, and charttime
df = pd.merge(vital_signs_df, combined_df, on=['subject_id', 'hadm_id', 'charttime'], how='outer')

# Sort by subject_id and charttime
df = df.sort_values(by=['subject_id', 'charttime'])

# %% [markdown]
# ### Data frame

# %%
df
# Out:
#          subject_id   hadm_id     stay_id            charttime   age  \
# 328        10002428  28662225  33987268.0  2156-04-12 17:25:00  80.0
# 329        10002428  28662225  33987268.0  2156-04-12 17:26:00  80.0
# 330        10002428  28662225  33987268.0  2156-04-12 17:27:00  80.0
# 331        10002428  28662225  33987268.0  2156-04-12 17:30:00  80.0
# 332        10002428  28662225  33987268.0  2156-04-12 17:45:00  80.0
# ...             ...       ...         ...                  ...   ...
# 1370581    19997367  21508795         NaN  2127-04-13 05:52:00   NaN
# 1370582    19997367  21508795         NaN  2127-04-14 06:42:00   NaN
# 1370583    19997367  21508795         NaN  2127-04-15 06:50:00   NaN
# 1370584    19997367  21508795         NaN  2127-04-16 10:15:00   NaN
# 1370585    19997367  21508795         NaN  2127-04-16 17:21:00   NaN
#
#          heart_rate  temperature  resp_rate  systolic_bp  diastolic_bp  \
# 328             NaN        102.9        NaN          NaN           NaN
# 329           124.0          NaN       25.0          NaN           NaN
# 330             NaN          NaN        NaN         87.0          42.0
# 331           120.0          NaN       29.0         94.0          37.0
# 332           134.0        102.9       22.0         92.0          51.0
# ...             ...          ...        ...          ...           ...
# 1370581         NaN          NaN        NaN          NaN           NaN
# 1370582         NaN          NaN        NaN          NaN           NaN
# 1370583         NaN          NaN        NaN          NaN           NaN
# 1370584         NaN          NaN        NaN          NaN           NaN
# 1370585         NaN          NaN        NaN          NaN           NaN
#
#          blood_oxygen_saturation  co2_partial_pressure  white_blood_cells  \
# 328                          NaN                   NaN                NaN
# 329                         90.0                   NaN                NaN
# 330                          NaN                   NaN                NaN
# 331                         93.0                   NaN                NaN
# 332                         94.0                   NaN                NaN
# ...                          ...                   ...                ...
# 1370581                      NaN                   NaN               12.0
# 1370582                      NaN                   NaN               11.4
# 1370583                      NaN                   NaN                7.0
# 1370584                      NaN                   NaN                9.5
# 1370585                      NaN                   NaN                NaN
#
#          ph_value
# 328           NaN
# 329           NaN
# 330           NaN
# 331           NaN
# 332           NaN
# ...           ...
# 1370581       NaN
# 1370582       NaN
# 1370583       NaN
# 1370584       NaN
# 1370585       6.0
#
# [1370586 rows x 14 columns]

# %%
# Aggregate data into hourly intervals
df['charttime'] = pd.to_datetime(df['charttime'])

df.set_index('charttime', inplace=True)

# %% [markdown]
# ## Time series Data Analysis

# %% [markdown]
# #### Hourly interval data

# %%
# Step : 1 Resample the data to hourly intervals, calculating the mean for each hour
hourly_df = df.groupby(['subject_id', 'hadm_id', 'stay_id']).resample('1H').mean()
# Out:
# /var/folders/xg/f264hrzn7j7gdpk7gdvq7ffh0000gn/T/ipykernel_94920/3592301732.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly_df = df.groupby(['subject_id', 'hadm_id', 'stay_id']).resample('1H').mean()

# %%
# Check if the columns already exist, and if so, drop them before resetting the index
hourly_df = hourly_df.drop(columns=['stay_id', 'subject_id', 'hadm_id'], errors='ignore').reset_index()

# %%
hourly_df = hourly_df.reset_index()

# %% [markdown]
# ###  Handling missing Value using carry forward and backward imputation

# %%
# Step 2: Implement carry forward/backward imputation
hourly_df = hourly_df.groupby(['subject_id', 'hadm_id', 'stay_id']).apply(lambda group: group.fillna(method='ffill').fillna(method='bfill'))
# Out:
# /var/folders/xg/f264hrzn7j7gdpk7gdvq7ffh0000gn/T/ipykernel_94920/1621308365.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   hourly_df = hourly_df.groupby(['subject_id', 'hadm_id', 'stay_id']).apply(lambda group: group.fillna(method='ffill').fillna(method='bfill'))
# /var/folders/xg/f264hrzn7j7gdpk7gdvq7ffh0000gn/T/ipykernel_94920/1621308365.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   hourly_df = hourly_df.groupby(['subject_id', 'hadm_id', 'stay_id']).apply(lambda group: group.fillna(method='ffill').fillna(method='bfill'))

# %%
hourly_df = hourly_df.drop(columns=['stay_id', 'subject_id', 'hadm_id'], errors='ignore').reset_index()

# %% [markdown]
# ### Sepsis Defination 1

# %%
def check_sirs_criteria(row):
    criteria_met = 0
    
    # Temperature abnormality in Fahrenheit
    if row['temperature'] < 96.8 or row['temperature'] > 100.4:
        criteria_met += 1
    
    # Heart rate abnormality
    if row['heart_rate'] > 90:
        criteria_met += 1
    
    # Respiratory rate abnormality
    if row['resp_rate'] > 20:
        criteria_met += 1
    
    # White blood cell count abnormality (using 1000s for the range of normal values)
    if pd.notna(row['white_blood_cells']):  # Check if WBC value is not null
        if row['white_blood_cells'] < 4.0 or row['white_blood_cells'] > 12.0:
            criteria_met += 1
    
    # Return whether 2 or more criteria are met
    return 1 if criteria_met >= 2 else 0

# %% [markdown]
# ### Checking 5 hr of Window if two above feature, high for patients, their first hour called speis_onset

# %%
# Step 3: Apply the 5-hour SIRS window check

# hourly_df = hourly_df.groupby(['subject_id', 'hadm_id', 'stay_id']).apply(check_sirs_window)
def check_sirs_window(df):
    df['sirs_criteria_met'] = df.apply(check_sirs_criteria, axis=1)
    df['sirs_window'] = df['sirs_criteria_met'].rolling(window=5).sum()
    
    # Mark the sepsis onset at the first hour of the 5-hour interval
    df['sepsis_onset'] = 0
    df.loc[df['sirs_window'] >= 5, 'sepsis_onset'] = 1
    
    # Shift sepsis onset to the first hour of the 5-hour window
    df['sepsis_onset'] = df['sepsis_onset'].shift(-4).fillna(0).astype(int)
    
    return df

hourly_df = hourly_df.groupby(['subject_id', 'hadm_id', 'stay_id']).apply(check_sirs_window)
# Out:
# /var/folders/xg/f264hrzn7j7gdpk7gdvq7ffh0000gn/T/ipykernel_94920/3420506990.py:17: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   hourly_df = hourly_df.groupby(['subject_id', 'hadm_id', 'stay_id']).apply(check_sirs_window)

# %%
hourly_df
# Out:
#                                        subject_id   hadm_id     stay_id  \
# subject_id hadm_id  stay_id
# 10002428   23473524 35479615.0 0         10002428  23473524  35479615.0
#                                1         10002428  23473524  35479615.0
#                                2         10002428  23473524  35479615.0
#                                3         10002428  23473524  35479615.0
#                                4         10002428  23473524  35479615.0
# ...                                           ...       ...         ...
# 19997367   21508795 36980198.0 906461    19997367  21508795  36980198.0
#                                906462    19997367  21508795  36980198.0
#                                906463    19997367  21508795  36980198.0
#                                906464    19997367  21508795  36980198.0
#                                906465    19997367  21508795  36980198.0
#
#                                        level_3   index           charttime  \
# subject_id hadm_id  stay_id
# 10002428   23473524 35479615.0 0             0       0 2156-05-11 16:00:00
#                                1             1       1 2156-05-11 17:00:00
#                                2             2       2 2156-05-11 18:00:00
#                                3             3       3 2156-05-11 19:00:00
#                                4             4       4 2156-05-11 20:00:00
# ...                                        ...     ...                 ...
# 19997367   21508795 36980198.0 906461   906461  906461 2127-04-06 16:00:00
#                                906462   906462  906462 2127-04-06 17:00:00
#                                906463   906463  906463 2127-04-06 18:00:00
#                                906464   906464  906464 2127-04-06 19:00:00
#                                906465   906465  906465 2127-04-06 20:00:00
#
#                                         age  heart_rate  temperature  \
# subject_id hadm_id  stay_id
# 10002428   23473524 35479615.0 0       80.0        68.2         97.2
#                                1       80.0        68.0         97.2
#                                2       80.0        73.0         97.2
#                                3       80.0        85.0         97.2
#                                4       80.0       102.0         97.7
# ...                                     ...         ...          ...
# 19997367   21508795 36980198.0 906461  63.0        98.0         97.3
#                                906462  63.0        98.0         97.3
#                                906463  63.0        98.0         97.3
#                                906464  63.0       102.0         97.3
#                                906465  63.0       103.0         98.1
#
#                                        resp_rate  systolic_bp  diastolic_bp  \
# subject_id hadm_id  stay_id
# 10002428   23473524 35479615.0 0            17.8        128.2          65.2
#                                1            18.0        106.0          58.0
#                                2            18.0        122.0          63.0
#                                3            18.0        103.0          51.0
#                                4            19.0         99.0          52.0
# ...                                          ...          ...           ...
# 19997367   21508795 36980198.0 906461       18.0         99.0          55.0
#                                906462       17.0         99.0          55.0
#                                906463       17.0        101.0          48.0
#                                906464       21.0         99.0          48.0
#                                906465       20.0         99.0          87.0
#
#                                        blood_oxygen_saturation  \
# subject_id hadm_id  stay_id
# 10002428   23473524 35479615.0 0                         100.0
#                                1                         100.0
#                                2                         100.0
#                                3                          99.0
#                                4                          98.0
# ...                                                        ...
# 19997367   21508795 36980198.0 906461                     96.0
#                                906462                     99.0
#                                906463                     98.0
#                                906464                     98.0
#                                906465                     97.0
#
#                                        co2_partial_pressure  \
# subject_id hadm_id  stay_id
# 10002428   23473524 35479615.0 0                       46.0
#                                1                       46.0
#                                2                       46.0
#                                3                       46.0
#                                4                       46.0
# ...                                                     ...
# 19997367   21508795 36980198.0 906461                   NaN
#                                906462                   NaN
#                                906463                   NaN
#                                906464                   NaN
#                                906465                   NaN
#
#                                        white_blood_cells  ph_value  \
# subject_id hadm_id  stay_id
# 10002428   23473524 35479615.0 0                     NaN      7.35
#                                1                     NaN      7.35
#                                2                     NaN      7.35
#                                3                     NaN      7.35
#                                4                     NaN      7.35
# ...                                                  ...       ...
# 19997367   21508795 36980198.0 906461                7.6       NaN
#                                906462                7.6       NaN
#                                906463                7.6       NaN
#                                906464                7.6       NaN
#                                906465                7.6       NaN
#
#                                        sirs_criteria_met  sirs_window  \
# subject_id hadm_id  stay_id
# 10002428   23473524 35479615.0 0                       0          NaN
#                                1                       0          NaN
#                                2                       0          NaN
#                                3                       0          NaN
#                                4                       0          0.0
# ...                                                  ...          ...
# 19997367   21508795 36980198.0 906461                  0          1.0
#                                906462                  0          1.0
#                                906463                  0          1.0
#                                906464                  1          2.0
#                                906465                  0          1.0
#
#                                        sepsis_onset
# subject_id hadm_id  stay_id
# 10002428   23473524 35479615.0 0                  0
#                                1                  0
#                                2                  0
#                                3                  0
#                                4                  0
# ...                                             ...
# 19997367   21508795 36980198.0 906461             0
#                                906462             0
#                                906463             0
#                                906464             0
#                                906465             0
#
# [906466 rows x 19 columns]

# %%
# Check if the columns already exist, and if so, drop them before resetting the index
hourly_df = hourly_df.drop(columns=['stay_id', 'subject_id', 'hadm_id','level_3'], errors='ignore').reset_index()

# %%
hourly_df.drop(columns = ['sirs_window','sirs_criteria_met'],inplace = True)

# %%
hourly_df
# Out:
#         subject_id   hadm_id     stay_id  level_3   index           charttime  \
# 0         10002428  23473524  35479615.0        0       0 2156-05-11 16:00:00
# 1         10002428  23473524  35479615.0        1       1 2156-05-11 17:00:00
# 2         10002428  23473524  35479615.0        2       2 2156-05-11 18:00:00
# 3         10002428  23473524  35479615.0        3       3 2156-05-11 19:00:00
# 4         10002428  23473524  35479615.0        4       4 2156-05-11 20:00:00
# ...            ...       ...         ...      ...     ...                 ...
# 906461    19997367  21508795  36980198.0   906461  906461 2127-04-06 16:00:00
# 906462    19997367  21508795  36980198.0   906462  906462 2127-04-06 17:00:00
# 906463    19997367  21508795  36980198.0   906463  906463 2127-04-06 18:00:00
# 906464    19997367  21508795  36980198.0   906464  906464 2127-04-06 19:00:00
# 906465    19997367  21508795  36980198.0   906465  906465 2127-04-06 20:00:00
#
#          age  heart_rate  temperature  resp_rate  systolic_bp  diastolic_bp  \
# 0       80.0        68.2         97.2       17.8        128.2          65.2
# 1       80.0        68.0         97.2       18.0        106.0          58.0
# 2       80.0        73.0         97.2       18.0        122.0          63.0
# 3       80.0        85.0         97.2       18.0        103.0          51.0
# 4       80.0       102.0         97.7       19.0         99.0          52.0
# ...      ...         ...          ...        ...          ...           ...
# 906461  63.0        98.0         97.3       18.0         99.0          55.0
# 906462  63.0        98.0         97.3       17.0         99.0          55.0
# 906463  63.0        98.0         97.3       17.0        101.0          48.0
# 906464  63.0       102.0         97.3       21.0         99.0          48.0
# 906465  63.0       103.0         98.1       20.0         99.0          87.0
#
#         blood_oxygen_saturation  co2_partial_pressure  white_blood_cells  \
# 0                         100.0                  46.0                NaN
# 1                         100.0                  46.0                NaN
# 2                         100.0                  46.0                NaN
# 3                          99.0                  46.0                NaN
# 4                          98.0                  46.0                NaN
# ...                         ...                   ...                ...
# 906461                     96.0                   NaN                7.6
# 906462                     99.0                   NaN                7.6
# 906463                     98.0                   NaN                7.6
# 906464                     98.0                   NaN                7.6
# 906465                     97.0                   NaN                7.6
#
#         ph_value  sepsis_onset
# 0           7.35             0
# 1           7.35             0
# 2           7.35             0
# 3           7.35             0
# 4           7.35             0
# ...          ...           ...
# 906461       NaN             0
# 906462       NaN             0
# 906463       NaN             0
# 906464       NaN             0
# 906465       NaN             0
#
# [906466 rows x 17 columns]

# %%
hourly_df = hourly_df.drop(columns=['level_3','index'], errors='ignore')

# %% [markdown]
# ### Normalize the data

# %%
# Step 4: Normalize the data
scaler = MinMaxScaler()
numerical_columns = ['age','heart_rate', 'temperature', 'resp_rate', 'systolic_bp', 'diastolic_bp', 'blood_oxygen_saturation', 'co2_partial_pressure', 'white_blood_cells', 'ph_value']
hourly_df[numerical_columns] = scaler.fit_transform(hourly_df[numerical_columns])

# %%
hourly_df
# Out:
#         subject_id   hadm_id     stay_id           charttime       age  \
# 0         10002428  23473524  35479615.0 2156-05-11 16:00:00  0.849315
# 1         10002428  23473524  35479615.0 2156-05-11 17:00:00  0.849315
# 2         10002428  23473524  35479615.0 2156-05-11 18:00:00  0.849315
# 3         10002428  23473524  35479615.0 2156-05-11 19:00:00  0.849315
# 4         10002428  23473524  35479615.0 2156-05-11 20:00:00  0.849315
# ...            ...       ...         ...                 ...       ...
# 906461    19997367  21508795  36980198.0 2127-04-06 16:00:00  0.616438
# 906462    19997367  21508795  36980198.0 2127-04-06 17:00:00  0.616438
# 906463    19997367  21508795  36980198.0 2127-04-06 18:00:00  0.616438
# 906464    19997367  21508795  36980198.0 2127-04-06 19:00:00  0.616438
# 906465    19997367  21508795  36980198.0 2127-04-06 20:00:00  0.616438
#
#         heart_rate  temperature  resp_rate  systolic_bp  diastolic_bp  \
# 0         0.007861     0.097395   0.000075     0.001104      0.000686
# 1         0.007851     0.097395   0.000076     0.000913      0.000610
# 2         0.008102     0.097395   0.000076     0.001051      0.000662
# 3         0.008706     0.097395   0.000076     0.000887      0.000536
# 4         0.009562     0.097896   0.000080     0.000853      0.000547
# ...            ...          ...        ...          ...           ...
# 906461    0.009360     0.097495   0.000076     0.000853      0.000578
# 906462    0.009360     0.097495   0.000071     0.000853      0.000578
# 906463    0.009360     0.097495   0.000071     0.000870      0.000505
# 906464    0.009562     0.097495   0.000088     0.000853      0.000505
# 906465    0.009612     0.098297   0.000084     0.000853      0.000915
#
#         blood_oxygen_saturation  co2_partial_pressure  white_blood_cells  \
# 0                      0.000200              0.017809                NaN
# 1                      0.000200              0.017809                NaN
# 2                      0.000200              0.017809                NaN
# 3                      0.000198              0.017809                NaN
# 4                      0.000196              0.017809                NaN
# ...                         ...                   ...                ...
# 906461                 0.000192                   NaN           0.034771
# 906462                 0.000198                   NaN           0.034771
# 906463                 0.000196                   NaN           0.034771
# 906464                 0.000196                   NaN           0.034771
# 906465                 0.000194                   NaN           0.034771
#
#         ph_value  sepsis_onset
# 0         0.5875             0
# 1         0.5875             0
# 2         0.5875             0
# 3         0.5875             0
# 4         0.5875             0
# ...          ...           ...
# 906461       NaN             0
# 906462       NaN             0
# 906463       NaN             0
# 906464       NaN             0
# 906465       NaN             0
#
# [906466 rows x 15 columns]

# %% [markdown]
# ### Now, we are replacing Nan with 0 - Rnn we are padding nan with 0

# %% [markdown]
# We’re taking this approach because, in time series analysis, every piece of patient data is crucial. Padding missing values with zeros doesn’t negatively impact performance and allows the model to learn from other patients’ data as well. For example, if a patient’s temperature is missing but their white blood cell count is elevated, this is still valuable information. Removing data points solely due to missing temperature values could lead the model to overlook critical patterns.

# %%
hourly_df.fillna(0, inplace=True)

# %% [markdown]
# ### Sepsis onset

# %%
hourly_df['sepsis_onset'].value_counts()
# Out:
# sepsis_onset
# 0    623866
# 1    282600
# Name: count, dtype: int64

# %% [markdown]
# ### Filttering the subject Id we required at least 130

# %%
subject_counts = hourly_df['subject_id'].value_counts()

valid_subject_ids = subject_counts[subject_counts >= 130].index

filtered_hourly_df = hourly_df[hourly_df['subject_id'].isin(valid_subject_ids)]

print(f"Original dataframe shape: {hourly_df.shape}")
print(f"Filtered dataframe shape: {filtered_hourly_df.shape}")
# Out:
# Original dataframe shape: (906466, 15)
# Filtered dataframe shape: (738306, 15)

# %%
filtered_hourly_df['subject_id'].value_counts()
# Out:
# subject_id
# 16454913    3559
# 18295542    2994
# 14411859    2689
# 15689523    2209
# 10670818    1958
#             ...
# 13670977     130
# 11305002     130
# 18085171     130
# 12115948     130
# 13114866     130
# Name: count, Length: 1930, dtype: int64

# %%
hourly_df = filtered_hourly_df.copy()

# %% [markdown]
# ### Final Dataframe

# %%
hourly_df
# Out:
#         subject_id   hadm_id     stay_id           charttime       age  \
# 0         10002428  23473524  35479615.0 2156-05-11 16:00:00  0.849315
# 1         10002428  23473524  35479615.0 2156-05-11 17:00:00  0.849315
# 2         10002428  23473524  35479615.0 2156-05-11 18:00:00  0.849315
# 3         10002428  23473524  35479615.0 2156-05-11 19:00:00  0.849315
# 4         10002428  23473524  35479615.0 2156-05-11 20:00:00  0.849315
# ...            ...       ...         ...                 ...       ...
# 906461    19997367  21508795  36980198.0 2127-04-06 16:00:00  0.616438
# 906462    19997367  21508795  36980198.0 2127-04-06 17:00:00  0.616438
# 906463    19997367  21508795  36980198.0 2127-04-06 18:00:00  0.616438
# 906464    19997367  21508795  36980198.0 2127-04-06 19:00:00  0.616438
# 906465    19997367  21508795  36980198.0 2127-04-06 20:00:00  0.616438
#
#         heart_rate  temperature  resp_rate  systolic_bp  diastolic_bp  \
# 0         0.007861     0.097395   0.000075     0.001104      0.000686
# 1         0.007851     0.097395   0.000076     0.000913      0.000610
# 2         0.008102     0.097395   0.000076     0.001051      0.000662
# 3         0.008706     0.097395   0.000076     0.000887      0.000536
# 4         0.009562     0.097896   0.000080     0.000853      0.000547
# ...            ...          ...        ...          ...           ...
# 906461    0.009360     0.097495   0.000076     0.000853      0.000578
# 906462    0.009360     0.097495   0.000071     0.000853      0.000578
# 906463    0.009360     0.097495   0.000071     0.000870      0.000505
# 906464    0.009562     0.097495   0.000088     0.000853      0.000505
# 906465    0.009612     0.098297   0.000084     0.000853      0.000915
#
#         blood_oxygen_saturation  co2_partial_pressure  white_blood_cells  \
# 0                      0.000200              0.017809           0.000000
# 1                      0.000200              0.017809           0.000000
# 2                      0.000200              0.017809           0.000000
# 3                      0.000198              0.017809           0.000000
# 4                      0.000196              0.017809           0.000000
# ...                         ...                   ...                ...
# 906461                 0.000192              0.000000           0.034771
# 906462                 0.000198              0.000000           0.034771
# 906463                 0.000196              0.000000           0.034771
# 906464                 0.000196              0.000000           0.034771
# 906465                 0.000194              0.000000           0.034771
#
#         ph_value  sepsis_onset
# 0         0.5875             0
# 1         0.5875             0
# 2         0.5875             0
# 3         0.5875             0
# 4         0.5875             0
# ...          ...           ...
# 906461    0.0000             0
# 906462    0.0000             0
# 906463    0.0000             0
# 906464    0.0000             0
# 906465    0.0000             0
#
# [738306 rows x 15 columns]

# %% [markdown]
# ## Time Series Analysis

# %% [markdown]
# sequences, labels

# %%
def create_sequences_with_variable_prediction_time(data, window_size, prediction_time):
    sequences = []
    labels = []
    
    # Group by subject_id to ensure sequences are generated separately for each subject
    for subject_id, group in data.groupby('subject_id'):
        group = group.reset_index(drop=True)  # Reset index for each subject
        
        # Drop non-relevant columns
        group = group.drop(columns=['subject_id', 'hadm_id', 'stay_id', 'charttime', 'sepsis_onset'])
        
        for i in range(len(group) - window_size - prediction_time):
            sequence = group.iloc[i:i+window_size].values  # Get look-back window
            label = data['sepsis_onset'].iloc[i+window_size + prediction_time - 1]  # Predict n hours ahead
            sequences.append(sequence)
            labels.append(label)
    
    return np.array(sequences), np.array(labels)

# %% [markdown]
# ###  Based on 10 hr data , predict 3 hr before speis onset in patients

# %%
window_size = 10  # Look-back period
prediction_time = 3  # Predict 3 hours ahead

sequences, labels = create_sequences_with_variable_prediction_time(hourly_df, window_size, prediction_time)

# %%
sequences
# Out:
# array([[[0.84931507, 0.0078607 , 0.09739479, ..., 0.01780875,
#          0.        , 0.5875    ],
#         [0.84931507, 0.00785064, 0.09739479, ..., 0.01780875,
#          0.        , 0.5875    ],
#         [0.84931507, 0.00810226, 0.09739479, ..., 0.01780875,
#          0.        , 0.5875    ],
#         ...,
#         [0.84931507, 0.00991394, 0.09789579, ..., 0.01780875,
#          0.        , 0.5875    ],
#         [0.84931507, 0.00956167, 0.10230461, ..., 0.01277584,
#          0.        , 0.6075    ],
#         [0.84931507, 0.009612  , 0.10230461, ..., 0.01277584,
#          0.        , 0.6075    ]],
#
#        [[0.84931507, 0.00785064, 0.09739479, ..., 0.01780875,
#          0.        , 0.5875    ],
#         [0.84931507, 0.00810226, 0.09739479, ..., 0.01780875,
#          0.        , 0.5875    ],
#         [0.84931507, 0.00870615, 0.09739479, ..., 0.01780875,
#          0.        , 0.5875    ],
#         ...,
#         [0.84931507, 0.00956167, 0.10230461, ..., 0.01277584,
#          0.        , 0.6075    ],
#         [0.84931507, 0.009612  , 0.10230461, ..., 0.01277584,
#          0.        , 0.6075    ],
#         [0.84931507, 0.0090081 , 0.0997996 , ..., 0.01277584,
#          0.        , 0.6075    ]],
#
#        [[0.84931507, 0.00810226, 0.09739479, ..., 0.01780875,
#          0.        , 0.5875    ],
#         [0.84931507, 0.00870615, 0.09739479, ..., 0.01780875,
#          0.        , 0.5875    ],
#         [0.84931507, 0.00956167, 0.09789579, ..., 0.01780875,
#          0.        , 0.5875    ],
#         ...,
#         [0.84931507, 0.009612  , 0.10230461, ..., 0.01277584,
#          0.        , 0.6075    ],
#         [0.84931507, 0.0090081 , 0.0997996 , ..., 0.01277584,
#          0.        , 0.6075    ],
#         [0.84931507, 0.0088068 , 0.0997996 , ..., 0.01277584,
#          0.        , 0.6075    ]],
#
#        ...,
#
#        [[0.61643836, 0.0090081 , 0.09759519, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.0090081 , 0.09759519, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.0090081 , 0.09759519, ..., 0.        ,
#          0.03477051, 0.        ],
#         ...,
#         [0.61643836, 0.00931005, 0.09749499, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.0092094 , 0.09749499, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.00925973, 0.09749499, ..., 0.        ,
#          0.03477051, 0.        ]],
#
#        [[0.61643836, 0.0090081 , 0.09759519, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.0090081 , 0.09759519, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.0090081 , 0.09759519, ..., 0.        ,
#          0.03477051, 0.        ],
#         ...,
#         [0.61643836, 0.0092094 , 0.09749499, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.00925973, 0.09749499, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.00931005, 0.09749499, ..., 0.        ,
#          0.03477051, 0.        ]],
#
#        [[0.61643836, 0.0090081 , 0.09759519, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.0090081 , 0.09759519, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.00925973, 0.09759519, ..., 0.        ,
#          0.03477051, 0.        ],
#         ...,
#         [0.61643836, 0.00925973, 0.09749499, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.00931005, 0.09749499, ..., 0.        ,
#          0.03477051, 0.        ],
#         [0.61643836, 0.00936037, 0.09749499, ..., 0.        ,
#          0.03477051, 0.        ]]])

# %% [markdown]
# ## Class imblance - solve by using Smoke oversampling

# %%
# Split the sequences and labels into training, validation, and testing sets
X_train_full, X_test, y_train_full, y_test = train_test_split(sequences, labels, test_size=0.2, random_state=42)

# Reshape data into 2D for SMOTE (reshape to [n_samples, window_size * n_features])
n_samples, window_size, n_features = X_train_full.shape
X_train_reshaped = X_train_full.reshape((n_samples, window_size * n_features))

# Appling SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_reshaped, y_train_full)

# Reshape data back into 3D for training (reshape to [n_samples, window_size, n_features])
X_train_resampled = X_train_resampled.reshape((X_train_resampled.shape[0], window_size, n_features))

# Split the resampled training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_resampled, y_train_resampled, test_size=0.25, random_state=42)

# %%
# Normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_val = scaler.transform(X_val.reshape(-1, X_val.shape[-1])).reshape(X_val.shape)
X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# %% [markdown]
# ## LSTM Model with 2 hidden layer

# %%
# Define the LSTM model
model1 = Sequential()

# Add an LSTM layer
model1.add(LSTM(units=64, return_sequences=True, input_shape=(window_size, sequences.shape[2])))
model1.add(LSTM(units=64, return_sequences=False))

# Add a Dense output layer for binary classification
model1.add(Dense(1, activation='sigmoid'))

# Compile the model
model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print the model summary
model1.summary()
# Out:
# 2024-10-29 10:41:03.058199: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Max
# 2024-10-29 10:41:03.058232: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2024-10-29 10:41:03.058239: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 13.50 GB
# 2024-10-29 10:41:03.058257: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-10-29 10:41:03.058272: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/sadhikrupa/Library/Python/3.9/lib/python/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        19,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,289 (204.25 KB)
#  Trainable params: 52,289 (204.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define early stopping to monitor validation loss with patience of 3 epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model with early stopping
history1 = model1.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    callbacks=[early_stopping]
)

# After training, evaluate the model on the test set
test_loss, test_accuracy = model1.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/50
# 2024-10-29 10:41:09.469190: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 253s 12ms/step - accuracy: 0.5461 - loss: 0.6867 - val_accuracy: 0.5599 - val_loss: 0.6803
# Epoch 2/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 253s 12ms/step - accuracy: 0.5626 - loss: 0.6795 - val_accuracy: 0.5730 - val_loss: 0.6731
# Epoch 3/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 249s 12ms/step - accuracy: 0.5761 - loss: 0.6715 - val_accuracy: 0.5840 - val_loss: 0.6636
# Epoch 4/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 249s 12ms/step - accuracy: 0.5853 - loss: 0.6630 - val_accuracy: 0.6003 - val_loss: 0.6515
# Epoch 5/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 246s 12ms/step - accuracy: 0.5991 - loss: 0.6514 - val_accuracy: 0.6089 - val_loss: 0.6424
# Epoch 6/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 252s 12ms/step - accuracy: 0.6125 - loss: 0.6401 - val_accuracy: 0.6297 - val_loss: 0.6263
# Epoch 7/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 250s 12ms/step - accuracy: 0.6265 - loss: 0.6267 - val_accuracy: 0.6441 - val_loss: 0.6079
# Epoch 8/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 252s 12ms/step - accuracy: 0.6436 - loss: 0.6115 - val_accuracy: 0.6634 - val_loss: 0.5923
# Epoch 9/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 250s 12ms/step - accuracy: 0.6631 - loss: 0.5923 - val_accuracy: 0.6766 - val_loss: 0.5804
# Epoch 10/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 249s 12ms/step - accuracy: 0.6826 - loss: 0.5733 - val_accuracy: 0.6933 - val_loss: 0.5643
# Epoch 11/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 245s 12ms/step - accuracy: 0.6995 - loss: 0.5560 - val_accuracy: 0.7067 - val_loss: 0.5469
# Epoch 12/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 254s 12ms/step - accuracy: 0.7148 - loss: 0.5405 - val_accuracy: 0.7354 - val_loss: 0.5179
# Epoch 13/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 254s 12ms/step - accuracy: 0.7304 - loss: 0.5222 - val_accuracy: 0.7118 - val_loss: 0.5487
# Epoch 14/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 255s 12ms/step - accuracy: 0.7397 - loss: 0.5093 - val_accuracy: 0.7297 - val_loss: 0.5216
# Epoch 15/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 255s 12ms/step - accuracy: 0.7513 - loss: 0.4951 - val_accuracy: 0.7696 - val_loss: 0.4724
# Epoch 16/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 255s 12ms/step - accuracy: 0.7602 - loss: 0.4831 - val_accuracy: 0.7703 - val_loss: 0.4705
# Epoch 17/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 255s 12ms/step - accuracy: 0.7673 - loss: 0.4731 - val_accuracy: 0.7806 - val_loss: 0.4538
# Epoch 18/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 255s 12ms/step - accuracy: 0.7753 - loss: 0.4619 - val_accuracy: 0.7716 - val_loss: 0.4709
# Epoch 19/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.7816 - loss: 0.4532 - val_accuracy: 0.7854 - val_loss: 0.4532
# Epoch 20/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.7855 - loss: 0.4476 - val_accuracy: 0.7925 - val_loss: 0.4408
# Epoch 21/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.7917 - loss: 0.4390 - val_accuracy: 0.7911 - val_loss: 0.4405
# Epoch 22/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.7953 - loss: 0.4345 - val_accuracy: 0.7994 - val_loss: 0.4301
# Epoch 23/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.8006 - loss: 0.4265 - val_accuracy: 0.8069 - val_loss: 0.4176
# Epoch 24/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.8023 - loss: 0.4219 - val_accuracy: 0.7902 - val_loss: 0.4433
# Epoch 25/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.8059 - loss: 0.4181 - val_accuracy: 0.8107 - val_loss: 0.4123
# Epoch 26/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.8092 - loss: 0.4119 - val_accuracy: 0.8039 - val_loss: 0.4210
# Epoch 27/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.8112 - loss: 0.4093 - val_accuracy: 0.8150 - val_loss: 0.4078
# Epoch 28/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.8133 - loss: 0.4041 - val_accuracy: 0.8195 - val_loss: 0.3964
# Epoch 29/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 256s 12ms/step - accuracy: 0.8162 - loss: 0.4010 - val_accuracy: 0.8200 - val_loss: 0.3941
# Epoch 30/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 257s 12ms/step - accuracy: 0.8171 - loss: 0.3981 - val_accuracy: 0.8232 - val_loss: 0.3944
# Epoch 31/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 257s 12ms/step - accuracy: 0.8204 - loss: 0.3932 - val_accuracy: 0.8248 - val_loss: 0.3925
# Epoch 32/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 257s 12ms/step - accuracy: 0.8222 - loss: 0.3894 - val_accuracy: 0.8253 - val_loss: 0.3896
# Epoch 33/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 257s 12ms/step - accuracy: 0.8235 - loss: 0.3881 - val_accuracy: 0.8185 - val_loss: 0.4004
# Epoch 34/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 257s 12ms/step - accuracy: 0.8242 - loss: 0.3868 - val_accuracy: 0.8153 - val_loss: 0.4072
# Epoch 35/50
# 20825/20825 ━━━━━━━━━━━━━━━━━━━━ 257s 12ms/step - accuracy: 0.8260 - loss: 0.3848 - val_accuracy: 0.7685 - val_loss: 0.4729
# 4458/4458 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8146 - loss: 0.4104
# Test Accuracy: 0.8139704465866089

# %%
model1.save("Lstm_10hr.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve, auc, confusion_matrix, classification_report

# %%
# Step 1: Calculate Probabilities and Predict Sepsis
y_pred_prob = model1.predict(X_test)
threshold = 0.5  # Adjust threshold if necessary
y_pred = (y_pred_prob >= threshold).astype(int)
# Out:
# 4458/4458 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step

# %% [markdown]
# ### Confusion Matrix

# %%
# Step 2: Plot the Confusion Matrix with Plotly
conf_matrix = confusion_matrix(y_test, y_pred)
fig_conf_matrix = px.imshow(
    conf_matrix,
    labels=dict(x="Predicted Label", y="True Label", color="Count"),
    x=['No Sepsis', 'Sepsis'],
    y=['No Sepsis', 'Sepsis'],
    title="Confusion Matrix",
    color_continuous_scale='Blues',
    text_auto=True 
)
fig_conf_matrix.show()

# %%
# ROC AUC Score
roc_auc = roc_auc_score(y_test, y_pred_prob)
print(f"ROC AUC Score: {roc_auc}")
# Out:
# ROC AUC Score: 0.8938220226804857

# %% [markdown]
# ### ROC AUC Curve

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
fig_roc = go.Figure()
fig_roc.add_trace(go.Scatter(x=fpr, y=tpr, mode='lines', name=f'ROC Curve (AUC = {roc_auc:.2f})', line=dict(color='darkorange', width=2)))
fig_roc.add_trace(go.Scatter(x=[0, 1], y=[0, 1], mode='lines', name='Random', line=dict(color='navy', width=2, dash='dash')))

fig_roc.update_layout(
    title="Receiver Operating Characteristic (ROC) Curve",
    xaxis_title="False Positive Rate",
    yaxis_title="True Positive Rate",
    template="plotly_white",
    width=1000,  # Width in pixels
    height=800   # Height in pixels
)

# Display the figure
fig_roc.show()

# %% [markdown]
# ### Model Accuracy And Loss

# %%
# Step 4: Plot Training and Validation Loss
fig_loss = go.Figure()
fig_loss.add_trace(go.Scatter(y=history1.history['loss'], mode='lines+markers', name='Training Loss', line=dict(color='blue')))
fig_loss.add_trace(go.Scatter(y=history1.history['val_loss'], mode='lines+markers', name='Validation Loss', line=dict(color='red')))
fig_loss.update_layout(
    title="Training and Validation Loss Over Epochs",
    xaxis_title="Epoch",
    yaxis_title="Loss",
    template="plotly_white",
    width=1000,  # Width in pixels
    height=800   # Height in pixels
)
fig_loss.show()

# Step 5: Plot Model Accuracy
fig_accuracy = go.Figure()
fig_accuracy.add_trace(go.Scatter(y=history1.history['accuracy'], mode='lines+markers', name='Training Accuracy', line=dict(color='green')))
fig_accuracy.add_trace(go.Scatter(y=history1.history['val_accuracy'], mode='lines+markers', name='Validation Accuracy', line=dict(color='orange')))
fig_accuracy.update_layout(
    title="Training and Validation Accuracy Over Epochs",
    xaxis_title="Epoch",
    yaxis_title="Accuracy",
    template="plotly_white",
    width=1000,  # Width in pixels
    height=800   # Height in pixels
)
fig_accuracy.show()

# %% [markdown]
# ### Classification Report

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87    111126
#            1       0.55      0.82      0.66     31518
#
#     accuracy                           0.81    142644
#    macro avg       0.75      0.82      0.77    142644
# weighted avg       0.86      0.81      0.83    142644

# %%
import numpy as np
from sklearn.metrics import accuracy_score

def permutation_importance_lstm(model, X_test, y_test):
    baseline_accuracy = model.evaluate(X_test, y_test, verbose=0)[1]  # Get baseline accuracy
    feature_importances = []

    for i in range(X_test.shape[2]):  # Iterate through each feature column
        X_test_permuted = np.array(X_test)  # Make a copy of X_test
        np.random.shuffle(X_test_permuted[:, :, i])  # Permute the current feature column

        # Re-evaluate the model on the permuted dataset
        permuted_accuracy = model.evaluate(X_test_permuted, y_test, verbose=0)[1]
        importance = baseline_accuracy - permuted_accuracy  # Measure the importance as performance drop
        feature_importances.append(importance)

    return feature_importances

# Usage
feature_importances = permutation_importance_lstm(model1, X_test, y_test)

# %%
feature_importances
# Out:
# [0.164780855178833,
#  0.001857757568359375,
#  0.0011426806449890137,
#  -0.00033652782440185547,
#  -0.0002874135971069336,
#  0.000518798828125,
#  1.4007091522216797e-05,
#  0.15875887870788574,
#  0.16061663627624512,
#  0.14785760641098022]

# %%
feature_names = ['age', 'heart_rate', 'temperature', 'resp_rate', 'systolic_bp', 'diastolic_bp', 'blood_oxygen_saturation', 'co2_partial_pressure', 'white_blood_cells', 'ph_value']

# %% [markdown]
# ### Feature Importances ( our final model )

# %%
# Create horizontal bar plot
fig = go.Figure(go.Bar(
    x=feature_importances,
    y=feature_names,
    orientation='h',
    marker=dict(color='teal'),
    text=[f"{imp:.4f}" for imp in feature_importances],
    textposition='auto'
))

# Update layout for better readability
fig.update_layout(
    title="Feature Importances",
    xaxis_title="Importance",
    yaxis_title="Features",
    template="plotly_white"
)

# Show plot
fig.show()
